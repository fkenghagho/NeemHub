# %%
print('This web interface is dedicated to share NEEMs (Narrative-Enabled Episodic Memories),as universal datasets, among researchers in the robotics community and inspect those NEEMs through queries.')
N=100
for i in range(N):
    print('The Id is: ', i)
# Out:
# This web interface is dedicated to share NEEMs (Narrative-Enabled Episodic Memories),as universal datasets, among researchers in the robotics community and inspect those NEEMs through queries.
# ('The Id is: ', 0)
# ('The Id is: ', 1)
# ('The Id is: ', 2)
# ('The Id is: ', 3)
# ('The Id is: ', 4)
# ('The Id is: ', 5)
# ('The Id is: ', 6)
# ('The Id is: ', 7)
# ('The Id is: ', 8)
# ('The Id is: ', 9)
# ('The Id is: ', 10)
# ('The Id is: ', 11)
# ('The Id is: ', 12)
# ('The Id is: ', 13)
# ('The Id is: ', 14)
# ('The Id is: ', 15)
# ('The Id is: ', 16)
# ('The Id is: ', 17)
# ('The Id is: ', 18)
# ('The Id is: ', 19)
# ('The Id is: ', 20)
# ('The Id is: ', 21)
# ('The Id is: ', 22)
# ('The Id is: ', 23)
# ('The Id is: ', 24)
# ('The Id is: ', 25)
# ('The Id is: ', 26)
# ('The Id is: ', 27)
# ('The Id is: ', 28)
# ('The Id is: ', 29)
# ('The Id is: ', 30)
# ('The Id is: ', 31)
# ('The Id is: ', 32)
# ('The Id is: ', 33)
# ('The Id is: ', 34)
# ('The Id is: ', 35)
# ('The Id is: ', 36)
# ...
